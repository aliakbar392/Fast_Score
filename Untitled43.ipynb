# %%
import feedparser as fp
import time
from datetime import datetime, timedelta
import pytz
from bs4 import BeautifulSoup as soup
import requests
import nltk
import pandas as pd
import io
import torch.nn as nn
import numpy as np
import scipy.spatial
from dateutil.relativedelta import relativedelta
from datetime import date
from sklearn.neighbors import NearestNeighbors

# %%
import torch
from pytorch_pretrained_bert import BertTokenizer, BertModel
tokenizer = BertTokenizer.from_pretrained('bert-base-multilingual-uncased')

# %%
model = BertModel.from_pretrained('bert-base-multilingual-uncased')
model.eval()
# Out:
# BertModel(
#   (embeddings): BertEmbeddings(
#     (word_embeddings): Embedding(105879, 768, padding_idx=0)
#     (position_embeddings): Embedding(512, 768)
#     (token_type_embeddings): Embedding(2, 768)
#     (LayerNorm): BertLayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (encoder): BertEncoder(
#     (layer): ModuleList(
#       (0): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): BertLayerNorm()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (1): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): BertLayerNorm()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (2): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): BertLayerNorm()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (3): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): BertLayerNorm()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (4): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): BertLayerNorm()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (5): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): BertLayerNorm()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (6): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): BertLayerNorm()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (7): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): BertLayerNorm()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (8): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): BertLayerNorm()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (9): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): BertLayerNorm()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (10): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): BertLayerNorm()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (11): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): BertLayerNorm()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#   )
#   (pooler): BertPooler(
#     (dense): Linear(in_features=768, out_features=768, bias=True)
#     (activation): Tanh()
#   )
# )

# %%
def segm_id(tokenized_text):
  z=0
  segments_ids=[0,0]
  segments_ids=[]
  for a in tokenized_text:
    if a == '|':
      z=1
    segments_ids.append(z)
  #print(segments_ids)
  return segments_ids

# %%
def average_it(encoded_layers,length):
  sum=0
  a=1
  for layer in encoded_layers:
    #sum=sum+layer
    if(a>10):
      sum=sum+layer    
#     if(a<12):
#       sum=sum+layer
    a+=1
  sum=sum/5
  sum=sum.squeeze()
  sum=torch.sum(sum,dim=0)
  sum=sum/length
  return sum

# %%
def DB_article_similarity(text):
    tokenized_text = tokenizer.tokenize(text)
    indexed_tokens = tokenizer.convert_tokens_to_ids(tokenized_text)
  # Convert inputs to PyTorch tensors
    tokens_tensor = torch.tensor([indexed_tokens])
    segments_ids=segm_id(tokenized_text)
    segments_tensors = torch.tensor([segments_ids])
    
    tokens_tensor = tokens_tensor.to('cuda')
    segments_tensors = segments_tensors.to('cuda')
    model.to('cuda')
    
    with torch.no_grad():
        encoded_layers, _ = model(tokens_tensor, segments_tensors)
        
    feature=average_it(encoded_layers,len(tokens_tensor))
    return feature

# %%
links=['http://zeenews.india.com/hindi/india.xml',
       'http://zeenews.india.com/hindi/world.xml',
       'https://www.amarujala.com/rss/breaking-news.xml',
       'http://feeds.feedburner.com/ndtvkhabar-india',
       'http://feeds.feedburner.com/ndtvkhabar-world'
       'http://feeds.feedburner.com/ndtvkhabar-latest'
       'https://navbharattimes.indiatimes.com/india/rssfeedsection/1564454.cms'
       'https://navbharattimes.indiatimes.com/world/rssfeedsection/2279801.cms']

# %%
db_links= ['https://www.bhaskar.com/rss-feed/1061/',
          'https://www.bhaskar.com/rss-feed/1125/']

# %%
# Getting the news article to form the corpus
utc = pytz.utc
df = pd.DataFrame()
posts=[]


for s in links:
    f = fp.parse(s)
    try:
         publisher = f['feed']['title']
    except KeyError:
        continue
    for e in f['entries']:
        try:
            when = e['updated_parsed']
        except KeyError:
             when = e['published_parsed']
        when =  utc.localize(datetime.fromtimestamp(time.mktime(when)))
        title = e['title']
        try:
            body = e['content']['value']
            
        except KeyError:
            body = e['summary']
        link = e['link']
        posts.append((when, publisher, title, link, body))
        df = pd.DataFrame(posts, columns=["Time", "Publisher","Title","Link","Body"])

# %%
df_db = pd.DataFrame()
posts_db=[]


for s in db_links:
    f = fp.parse(s)
    try:
         publisher= f['feed']['title']
    except KeyError:
        continue
    for e in f['entries']:
        try:
            when = e['updated_parsed']
        except KeyError:
             when = e['published_parsed']
        when =  utc.localize(datetime.fromtimestamp(time.mktime(when)))
        
        title = e['title']
        try:
            body = e['content']['value']
            
        except KeyError:
            body = e['summary']
        link = e['link']
        posts_db.append((when, publisher, title, link, body))
        df_db = pd.DataFrame(posts_db, columns=["Time", "Publisher","Title","Link","Body"])

# 44   <a href="/national/news/madhya-pradesh-rajasth...
# 45   <a href="/local/mp/news/jagat-prakash-nadda-bj...
# 430  <a href="https://www.bhaskar.com/international...
# 46   <a href="/national/news/more-than-1000-people-...
# 431  <a href="https://www.bhaskar.com/international...
# 47   <a href="/national/news/india-china-border-ten...
# 48   <a href="/national/news/dgca-issues-circular-r...

# %%
corpus=df['Title']

# %%
query=df_db1["Title"]
time=df_db1["Time"]

# %%
DB_art_similarity = nn.CosineSimilarity(dim=0, eps=1e-6)
rank=1
article_vector_in_corpus=torch.zeros((len(corpus),768))
corpus_id=0
for article in corpus:
    article_vector_in_corpus[corpus_id]=DB_article_similarity(article)
    corpus_id+=1
    
corpus_id=0
article_vector_tensorc=article_vector_in_corpus.squeeze()
article_vector_tensorc
# Out:
# tensor([[ 0.4810, -2.1878,  1.0685,  ..., -2.5293, -3.7965,  0.9333],
#         [ 0.4029, -0.2498,  0.1598,  ..., -4.9550, -4.4868, -0.3507],
#         [-0.9495, -1.0787,  0.4644,  ..., -0.7264, -3.4871, -1.4777],
#         ...,
#         [-1.6360, -1.2491,  0.8975,  ...,  0.1980, -4.4543, -0.4310],
#         [-0.4527,  1.1698, -1.2535,  ..., -1.2131, -1.4253,  1.5258],
#         [-4.3348, -3.9586,  0.7285,  ..., -3.8609, -1.2287,  2.1225]])

# %%
article_vector_in_query=torch.zeros((len(query),768))
query_id=0
for article in query:
    article_vector_in_query[query_id]=DB_article_similarity(article)
    query_id+=1
query_id=0
article_vector_tensorq=article_vector_in_query.squeeze()
article_vector_tensorq
# Out:
# tensor([[-6.3908, -2.4470, -4.6049,  ..., -0.9796, -3.5234, -1.8420],
#         [-1.2458, -1.7894, -2.7888,  ..., -0.8154, -2.5356,  1.6560],
#         [-2.5665, -4.8754, -2.1748,  ..., -4.1282, -4.3376,  5.9797],
#         ...,
#         [-1.4753, -3.8911, -2.2943,  ..., -0.3805, -3.5875, -0.3151],
#         [-2.4768, -4.7248, -1.0890,  ..., -0.7119, -6.0939,  3.1366],
#         [-3.7224, -3.8669, -1.5496,  ..., -3.9831, -8.9805,  4.2511]])

# %%
knn = NearestNeighbors(n_neighbors=10, metric='cosine')
knn.fit(article_vector_tensorc)
# Out:
# NearestNeighbors(algorithm='auto', leaf_size=30, metric='cosine',
#                  metric_params=None, n_jobs=None, n_neighbors=10, p=2,
#                  radius=1.0)

# %%
knn.kneighbors(article_vector_tensorc);

# %%
input_1=pd.concat([query,time],axis=1)

# %%
D, N = knn.kneighbors(article_vector_tensorq, n_neighbors=2, return_distance=True)

for input_text, time,distances, neighbors in zip(input_1.Title,input_1.Time, D, N):
    print("Input text = ", input_text, "\n")
    print("Time= ", time, "\n")
    for dist, neighbor_idx in zip(distances, neighbors):
        print("idx = ", neighbor_idx)
        print(df.Title[neighbor_idx])
        print(df.Time[neighbor_idx])
        diff_time=df.Time[neighbor_idx]-time
        print("Fast_Score ={}".format(diff_time/np.timedelta64(1,'m')),"\n")
# Out:
# Input text =  गोपालगंज में 14 और मधुबनी-नवादा में 8-8 लोगों की जान गई, 12 जिलों में बारिश का रेड अलर्ट
#
# Time=  2020-06-25 13:58:38+00:00
#
# idx =  19
# जम्मू-कश्मीर के सोपोर में सुरक्षाबलों की बड़ी कामयाबी, 2 आतंकियों को मार गिराया
# 2020-06-25 03:00:20+00:00
# Fast_Score =-658.3
#
# idx =  44
# पुलवामा में सुरक्षाबलों और आतंकियों के बीच मुठभेड़, दो से तीन आतंकी घिरे होने की आशंका
# 2020-06-25 00:53:42+00:00
# Fast_Score =-784.9333333333333
#
# Input text =  महाराष्ट्र में जिम और सलून खुलेंगे, पाकिस्तान में फंसे 204 भारतीयों की वापसी हुई, 14 दिन क्वारैंटाइन रहेंगे; देश में अब तक 4.74 लाख केस
#
# Time=  2020-06-25 13:55:08+00:00
#
# idx =  32
# सीमा विवाद पर भारत के कड़े रुख से ड्रैगन पस्त, LAC के 3 प्वाइंट से पीछे हटी चीनी सेना
# 2020-06-25 04:07:50+00:00
# Fast_Score =-587.3
#
# idx =  63
# लॉकडाउन में प्रभावित हुए रेहड़ी-पटरीवालों के लिए 1 जुलाई से शुरू होगी 'PM स्वनिधि योजना', मिलेगा सस्ता कर्ज
# 2020-06-25 11:22:18+00:00
# Fast_Score =-152.83333333333334
#
# Input text =  इसरो चीफ सिवन ने कहा- प्राइवेट कंपनियों के आने से हमारा स्पेस सेक्टर मजबूत होगा, टेक्नोलॉजी का बेहतर इस्तेमाल हो सकेगा
#
# Time=  2020-06-25 13:54:01+00:00
#
# idx =  63
# लॉकडाउन में प्रभावित हुए रेहड़ी-पटरीवालों के लिए 1 जुलाई से शुरू होगी 'PM स्वनिधि योजना', मिलेगा सस्ता कर्ज
# 2020-06-25 11:22:18+00:00
# Fast_Score =-151.71666666666667
#
# idx =  69
# Reality Check: लद्दाख संघर्ष के बाद चीनी सामान पर BAN की मांग है कितनी व्‍यावहारिक और क्‍या हैं अड़चनें..
# 2020-06-25 10:31:03+00:00
# Fast_Score =-202.96666666666667
#
# Input text =  इनकी तैयारी कर रहे बच्चों का नुकसान नहीं होगा लेकिन, बचे पेपर कैंसल होने से पढ़ाई की रिदम टूटने का डर
#
# Time=  2020-06-25 13:53:41+00:00
#
# idx =  63
# लॉकडाउन में प्रभावित हुए रेहड़ी-पटरीवालों के लिए 1 जुलाई से शुरू होगी 'PM स्वनिधि योजना', मिलेगा सस्ता कर्ज
# 2020-06-25 11:22:18+00:00
# Fast_Score =-151.38333333333333
#
# idx =  32
# सीमा विवाद पर भारत के कड़े रुख से ड्रैगन पस्त, LAC के 3 प्वाइंट से पीछे हटी चीनी सेना
# 2020-06-25 04:07:50+00:00
# Fast_Score =-585.85
#
# Input text =  सेंट्रल टीचर एलिजिबिलिटी टेस्ट अगले आदेश तक स्थगित, 5 जुलाई को होनी थी परीक्षा, नई तारीख की घोषणा जल्द
#
# Time=  2020-06-25 13:52:05+00:00
#
# idx =  63
# लॉकडाउन में प्रभावित हुए रेहड़ी-पटरीवालों के लिए 1 जुलाई से शुरू होगी 'PM स्वनिधि योजना', मिलेगा सस्ता कर्ज
# 2020-06-25 11:22:18+00:00
# Fast_Score =-149.78333333333333
#
# idx =  16
# तिरुपति बालाजी के भक्तों के लिए खुशखबरी, जल्द शुरू होने वाली है विमान सेवा
# 2020-06-25 05:48:12+00:00
# Fast_Score =-483.8833333333333
#
# Input text =  पाकिस्तान की सरकारी एयरलाइंस के 860 में से 150 पायलट नहीं उड़ा सकेंगे प्लेन, 262 पायलट्स का एग्जाम किसी और ने दिया था
#
# Time=  2020-06-25 13:50:26+00:00
#
# idx =  0
# बिहार में आकाशीय बिजली ने मचाया कोहराम, अब तक 83 लोगों की हुई मौत
# 2020-06-25 13:50:01+00:00
# Fast_Score =-0.4166666666666667
#
# idx =  32
# सीमा विवाद पर भारत के कड़े रुख से ड्रैगन पस्त, LAC के 3 प्वाइंट से पीछे हटी चीनी सेना
# 2020-06-25 04:07:50+00:00
# Fast_Score =-582.6
#
# Input text =  हर कोरोना मरीज को जांच के लिए कोविड केयर सेंटर जाना जरूरी नहीं, मेडिकल टीम ऐसे मरीजों का घर पर असेसमेंट करेगी
#
# Time=  2020-06-25 13:48:40+00:00
#
# idx =  69
# Reality Check: लद्दाख संघर्ष के बाद चीनी सामान पर BAN की मांग है कितनी व्‍यावहारिक और क्‍या हैं अड़चनें..
# 2020-06-25 10:31:03+00:00
# Fast_Score =-197.61666666666667
#
# idx =  34
# ऑस्ट्रेलिया के इस शहर में कोरोना ने बरपाया कहर, संक्रमण रोकने के लिए बुलानी पड़ी सेना
# 2020-06-24 16:48:36+00:00
# Fast_Score =-1260.0666666666666
#
# Input text =  Fair & Lovely क्रीम से हटेगा फेयर शब्द, यूनिलिवर कंपनी अपनी 45 साल पुरानी क्रीम का नाम बदलेगी
#
# Time=  2020-06-25 13:44:43+00:00
#
# idx =  63
# लॉकडाउन में प्रभावित हुए रेहड़ी-पटरीवालों के लिए 1 जुलाई से शुरू होगी 'PM स्वनिधि योजना', मिलेगा सस्ता कर्ज
# 2020-06-25 11:22:18+00:00
# Fast_Score =-142.41666666666666
#
# idx =  69
# Reality Check: लद्दाख संघर्ष के बाद चीनी सामान पर BAN की मांग है कितनी व्‍यावहारिक और क्‍या हैं अड़चनें..
# 2020-06-25 10:31:03+00:00
# Fast_Score =-193.66666666666666
#
# Input text =  यूरोप के 30 देशों में पिछले 2 हफ्ते में बढ़ा संक्रमण, तीन महीने बाद एफिल टावर दोबारा खोला गया; दुनिया में अब तक 95 लाख से ज्यादा मरीज
#
# Time=  2020-06-25 13:42:44+00:00
#
# idx =  12
# सीमा विवाद के बीच सरकार का बड़ा फैसला, लद्दाख में 54 मोबाइल टावर लगाने का काम शुरू
# 2020-06-25 07:45:05+00:00
# Fast_Score =-357.65
#
# idx =  63
# लॉकडाउन में प्रभावित हुए रेहड़ी-पटरीवालों के लिए 1 जुलाई से शुरू होगी 'PM स्वनिधि योजना', मिलेगा सस्ता कर्ज
# 2020-06-25 11:22:18+00:00
# Fast_Score =-140.43333333333334
#
# Input text =  केंद्रीय मंत्री रविशंकर प्रसाद ने कहा- चीन ने राजीव गांधी फाउंडेशन को डोनेशन दिया, कांग्रेस बताए कि उसने किस शर्त पर रुपये लिए
#
# Time=  2020-06-25 13:41:14+00:00
#
# idx =  61
# जेपी नड्डा ने राहुल से पूछा सवाल, राजीव गांधी फाउंडेशन को चीन से डोनेशन क्यों मिला?
# 2020-06-25 11:59:11+00:00
# Fast_Score =-102.05
#
# idx =  62
# चीन को लेकर कांग्रेस के हमले पर BJP का पलटवार, पूछा- 'क्या चीनी पार्टी से समझौता हुआ था?'
# 2020-06-25 11:24:34+00:00
# Fast_Score =-136.66666666666666
#
# Input text =  यूजर का डेटा लंबे समय तक स्टोर नहीं करेगा गूगल, 18 महीने बाद सर्च हिस्ट्री तो 36 महीने बाद यूट्यूब हिस्ट्री खुद डिलीट हो जाएगी
#
# Time=  2020-06-25 13:36:27+00:00
#
# idx =  30
# आज ही के दिन दुनिया को अलविदा कह गए थे किंग ऑफ पॉप माइकल जैक्सन
# 2020-06-25 02:54:29+00:00
# Fast_Score =-641.9666666666667
#
# idx =  56
# पेट्रोल, डीज़ल और रसोई गैस की बढ़ती कीमतों के विरोध में RJD नेता तेजस्वी यादव ने निकाला साइकिल मार्च
# 2020-06-25 13:08:40+00:00
# Fast_Score =-27.783333333333335
#
# Input text =  नड्डा का आरोप- राजीव गांधी फाउंडेशन को चीन की संस्थाओं से पैसा मिला, देश जानना चाहता है किस उद्देश्य से ये पैसा मिला
#
# Time=  2020-06-25 13:18:27+00:00
#
# idx =  61
# जेपी नड्डा ने राहुल से पूछा सवाल, राजीव गांधी फाउंडेशन को चीन से डोनेशन क्यों मिला?
# 2020-06-25 11:59:11+00:00
# Fast_Score =-79.26666666666667
#
# idx =  53
# लद्दाख में तनातनी के बीच सरकार ने कहा- 'चीनी सैनिकों ने आपसी सहमति के सभी मानदंडों की अवहेलना की'
# 2020-06-25 13:29:19+00:00
# Fast_Score =10.866666666666667
#
# Input text =  लॉकडाउन में पाकिस्तान में फंसे जम्मू-कश्मीर के 250 नागरिक भारत लौटे, चेकिंग के बाद बसों में गृहराज्य रवाना
#
# Time=  2020-06-25 13:08:46+00:00
#
# idx =  32
# सीमा विवाद पर भारत के कड़े रुख से ड्रैगन पस्त, LAC के 3 प्वाइंट से पीछे हटी चीनी सेना
# 2020-06-25 04:07:50+00:00
# Fast_Score =-540.9333333333333
#
# idx =  34
# ऑस्ट्रेलिया के इस शहर में कोरोना ने बरपाया कहर, संक्रमण रोकने के लिए बुलानी पड़ी सेना
# 2020-06-24 16:48:36+00:00
# Fast_Score =-1220.1666666666667
#
# Input text =  चीन ने गलवान से जवानों को पीछे बुलाया, मिलिट्री व्हीकल हटाए; पर देपसांग में तम्बू गाड़े और तोप भी पहुंचाईं
#
# Time=  2020-06-25 13:02:46+00:00
#
# idx =  62
# चीन को लेकर कांग्रेस के हमले पर BJP का पलटवार, पूछा- 'क्या चीनी पार्टी से समझौता हुआ था?'
# 2020-06-25 11:24:34+00:00
# Fast_Score =-98.2
#
# idx =  32
# सीमा विवाद पर भारत के कड़े रुख से ड्रैगन पस्त, LAC के 3 प्वाइंट से पीछे हटी चीनी सेना
# 2020-06-25 04:07:50+00:00
# Fast_Score =-534.9333333333333
#
# Input text =  175 नए मामले आए, 49 मरीज ऑक्सीजन पर तो 16 वेंटीलेटर पर लड़ रहे जिंदगी की जंग
#
# Time=  2020-06-25 13:00:47+00:00
#
# idx =  32
# सीमा विवाद पर भारत के कड़े रुख से ड्रैगन पस्त, LAC के 3 प्वाइंट से पीछे हटी चीनी सेना
# 2020-06-25 04:07:50+00:00
# Fast_Score =-532.95
#
# idx =  12
# सीमा विवाद के बीच सरकार का बड़ा फैसला, लद्दाख में 54 मोबाइल टावर लगाने का काम शुरू
# 2020-06-25 07:45:05+00:00
# Fast_Score =-315.7
#
# Input text =  पिछले 6 सालों में पाकिस्तान से देश में घुसपैठ की 146 कोशिशें नाकाम, सुरक्षाबलों ने ऐसा करने वाले 25 आतंकी ढेर किए
#
# Time=  2020-06-25 12:46:42+00:00
#
# idx =  44
# पुलवामा में सुरक्षाबलों और आतंकियों के बीच मुठभेड़, दो से तीन आतंकी घिरे होने की आशंका
# 2020-06-25 00:53:42+00:00
# Fast_Score =-713.0
#
# idx =  19
# जम्मू-कश्मीर के सोपोर में सुरक्षाबलों की बड़ी कामयाबी, 2 आतंकियों को मार गिराया
# 2020-06-25 03:00:20+00:00
# Fast_Score =-586.3666666666667
#
# Input text =  लगज़री एसयूवी सेगमेंट में  GLE  व  GLS  का दबदबा
#
# Time=  2020-06-25 12:40:30+00:00
#
# idx =  32
# सीमा विवाद पर भारत के कड़े रुख से ड्रैगन पस्त, LAC के 3 प्वाइंट से पीछे हटी चीनी सेना
# 2020-06-25 04:07:50+00:00
# Fast_Score =-512.6666666666666
#
# idx =  1
# Exclusive: चीन की एक-एक चाल पर नजर रखेगा 'ध्रुव', IIT बॉम्बे ने बनाया भारत का पहला नेविगेशन रिसीवर चिप
# 2020-06-25 12:54:42+00:00
# Fast_Score =14.2
#
# Input text =  राज्य में आईसीएसई की परीक्षा नहीं होंगी, एक सप्ताह में खुलेंगे जिम और सलून; मातोश्री के पास बंगले में कोरोना संक्रमित मिला
#
# Time=  2020-06-25 12:38:59+00:00
# idx =  59
# दिल्ली में अब कोरोना पॉजिटिव मरीज को COVID केयर सेंटर जाना अनिवार्य नहीं, फैसले से पीछे हटे अनिल बैजल
# 2020-06-25 12:12:41+00:00
# Fast_Score =-26.3
#
# idx =  49
# आंध्र प्रदेश : मरीजों में नहीं दिख रहे कोविड-19 के लक्षण, अचानक हो रही मौत
# 2020-06-25 00:55:12+00:00
# Fast_Score =-703.7833333333333
#
# Input text =  सरकार ने सुप्रीम कोर्ट में कहा- पिछले 3 एग्जाम्स के आधार पर 12वीं के स्टूडेंट्स का असेसमेंट होगा, वे बचे हुए पेपर बाद में भी दे सकेंगे
#
# Time=  2020-06-25 12:24:48+00:00
#
# idx =  69
# Reality Check: लद्दाख संघर्ष के बाद चीनी सामान पर BAN की मांग है कितनी व्‍यावहारिक और क्‍या हैं अड़चनें..
# 2020-06-25 10:31:03+00:00
# Fast_Score =-113.75
#
# idx =  62
# चीन को लेकर कांग्रेस के हमले पर BJP का पलटवार, पूछा- 'क्या चीनी पार्टी से समझौता हुआ था?'
# 2020-06-25 11:24:34+00:00
# Fast_Score =-60.233333333333334
#
# Input text =  पीसीबी ने कहा- खिलाड़ियों के वीजा की गारंटी ले बीसीसीआई, भारतीय बोर्ड का जवाब- पहले पीसीबी आतंकी हमले न होने की गारंटी दे
#
# Time=  2020-06-25 12:18:53+00:00
#
# idx =  43
# भारतीय क्रिकेट बोर्ड का मुंहतोड़ जवाब, आतंकी हमले न होने की गारंटी दे पाकिस्तान क्रिकेट बोर्ड
# 2020-06-25 01:00:51+00:00
# Fast_Score =-678.0333333333333
#
# idx =  13
# आपातकाल की बरसी पर PM मोदी का ट्वीट, 'लोकतंत्र की रक्षा करने वालों को नमन'
# 2020-06-25 07:35:53+00:00
# Fast_Score =-283.0
#
# Input text =  1 जुलाई से होने वाली ICSE एग्जाम्स भी रद्द, यहां भी CBSE की असेसमेंट प्रोसेस के आधार पर रिजल्ट तय होगा
#
# Time=  2020-06-25 12:12:47+00:00
#
# idx =  63
# लॉकडाउन में प्रभावित हुए रेहड़ी-पटरीवालों के लिए 1 जुलाई से शुरू होगी 'PM स्वनिधि योजना', मिलेगा सस्ता कर्ज
# 2020-06-25 11:22:18+00:00
# Fast_Score =-50.483333333333334
#
# idx =  69
# Reality Check: लद्दाख संघर्ष के बाद चीनी सामान पर BAN की मांग है कितनी व्‍यावहारिक और क्‍या हैं अड़चनें..
# 2020-06-25 10:31:03+00:00
# Fast_Score =-101.73333333333333
#
# Input text =  सुप्रीम कोर्ट के फैसले से परेशान स्टूडेंट्स, बोले- मेरिट बेसिस पर कॉलेजों में एडमिशन मुश्किल होगा
#
# Time=  2020-06-25 12:01:30+00:00
#
# idx =  63
# लॉकडाउन में प्रभावित हुए रेहड़ी-पटरीवालों के लिए 1 जुलाई से शुरू होगी 'PM स्वनिधि योजना', मिलेगा सस्ता कर्ज
# 2020-06-25 11:22:18+00:00
# Fast_Score =-39.2
#
# idx =  69
# Reality Check: लद्दाख संघर्ष के बाद चीनी सामान पर BAN की मांग है कितनी व्‍यावहारिक और क्‍या हैं अड़चनें..
# 2020-06-25 10:31:03+00:00
# Fast_Score =-90.45
#
# Input text =  रामदेव की रुचि सोया इंडस्ट्री ने 5 महीने में दिया 8391% का रिटर्न, 17 रुपए का शेयर 1435 रुपए का हुआ
#
# Time=  2020-06-25 11:50:13+00:00
#
# idx =  67
# दिल्ली दंगों में युवक की हत्या के मामले में चार्जशीट दाखिल, मामले में सात आरोपी
# 2020-06-25 10:48:04+00:00
# Fast_Score =-62.15
#
# idx =  10
# आपातकाल: रामविलास पासवान ने एक के बाद एक तीन ट्वीट कर कांग्रेस पर किया अटैक
# 2020-06-25 08:26:15+00:00
# Fast_Score =-203.96666666666667
#
# Input text =  विदेश मंत्री शाह महमूद कुरैशी ने कहा- चीन से तनाव के बीच भारत हमारे देश पर हमला कर सकता है
#
# Time=  2020-06-25 11:47:06+00:00
#
# idx =  62
# चीन को लेकर कांग्रेस के हमले पर BJP का पलटवार, पूछा- 'क्या चीनी पार्टी से समझौता हुआ था?'
# 2020-06-25 11:24:34+00:00
# Fast_Score =-22.533333333333335
#
# idx =  53
# लद्दाख में तनातनी के बीच सरकार ने कहा- 'चीनी सैनिकों ने आपसी सहमति के सभी मानदंडों की अवहेलना की'
# 2020-06-25 13:29:19+00:00
# Fast_Score =102.21666666666667
#
# Input text =  देश की राजधानी में कोरोना के साए में रोज 12 घंटे ड्यूटी कर रहे हैं सिक्युरिटी गार्ड्स, कहते हैं- भूखे रहने से बेहतर है काम कर लेना
#
# Time=  2020-06-25 11:46:08+00:00
#
# idx =  63
# लॉकडाउन में प्रभावित हुए रेहड़ी-पटरीवालों के लिए 1 जुलाई से शुरू होगी 'PM स्वनिधि योजना', मिलेगा सस्ता कर्ज
# 2020-06-25 11:22:18+00:00
# Fast_Score =-23.833333333333332
#
# idx =  32
# सीमा विवाद पर भारत के कड़े रुख से ड्रैगन पस्त, LAC के 3 प्वाइंट से पीछे हटी चीनी सेना
# 2020-06-25 04:07:50+00:00
# Fast_Score =-458.3
#
# Input text =  तीन दिन में तीसरी एयलाइन्स ने पाकिस्तान की उड़ानें बंद कीं; एतिहाद की फ्लाइट से हॉन्कॉन्ग पहुंचे 27 पाकिस्तानी पॉजिटिव पाए गए थे
#
# Time=  2020-06-25 11:25:41+00:00
#
# idx =  31
# PAK आतंकियों के लिये पनाहगाह, मुंबई हमले के मास्‍टरमाइंड के खिलाफ कार्रवाई नहीं हुई: US
# 2020-06-24 21:11:31+00:00
# Fast_Score =-854.1666666666666
#
# idx =  34
# ऑस्ट्रेलिया के इस शहर में कोरोना ने बरपाया कहर, संक्रमण रोकने के लिए बुलानी पड़ी सेना
# 2020-06-24 16:48:36+00:00
# Fast_Score =-1117.0833333333333
#
# Input text =  4.5 लाख मरीजों में से सिर्फ 4.16% को वेंटिलेटर की जरूरत पड़ी, 15.34% को आईसीयू में रखना पड़ा
#
# Time=  2020-06-25 11:16:24+00:00
#
# idx =  63
# लॉकडाउन में प्रभावित हुए रेहड़ी-पटरीवालों के लिए 1 जुलाई से शुरू होगी 'PM स्वनिधि योजना', मिलेगा सस्ता कर्ज
# 2020-06-25 11:22:18+00:00
# Fast_Score =5.9
#
# idx =  67
# दिल्ली दंगों में युवक की हत्या के मामले में चार्जशीट दाखिल, मामले में सात आरोपी
# 2020-06-25 10:48:04+00:00
# Fast_Score =-28.333333333333332
#
# Input text =  संवैधानिक बदलाव को लेकर आज से 7 दिन तक वोटिंग, कानून बना तो पुतिन 2036 तक राष्ट्रपति बने रह सकते हैं
#
# Time=  2020-06-25 10:58:45+00:00
#
# idx =  63
# लॉकडाउन में प्रभावित हुए रेहड़ी-पटरीवालों के लिए 1 जुलाई से शुरू होगी 'PM स्वनिधि योजना', मिलेगा सस्ता कर्ज
# 2020-06-25 11:22:18+00:00
# Fast_Score =23.55
#
# idx =  64
# कांग्रेस ने 45 साल पहले आज ही लोगों से छीने थे हक, यही पार्टी अब कर रही लोकतंत्र की बात: निर्मला सीतारमण
# 2020-06-25 11:09:09+00:00
# Fast_Score =10.4
#
# Input text =  राजस्थान के बाद महाराष्ट्र सरकार ने बाबा रामदेव की दवा पर पाबंदी लगाई, कहा- राज्य में नकली दवा बिकने नहीं देंगे
#
# Time=  2020-06-25 10:52:23+00:00
#
# idx =  8
# दिल्ली दंगा: नाम पूछने के बाद भीड़ ने की हत्या, चार्जशीट दाखिल, जानें पूरा मामला
# 2020-06-25 09:34:10+00:00
# Fast_Score =-78.21666666666667
#
# idx =  53
# लद्दाख में तनातनी के बीच सरकार ने कहा- 'चीनी सैनिकों ने आपसी सहमति के सभी मानदंडों की अवहेलना की'
# 2020-06-25 13:29:19+00:00
# Fast_Score =156.93333333333334
#
# Input text =  मोदी बोले- लोकतंत्र की रक्षा के लिए लड़ने वालों को नमन; शाह ने कहा- सत्ता के लालची परिवार ने गरीबों पर अत्याचार किए थे
#
# Time=  2020-06-25 10:20:48+00:00
#
# idx =  53
# लद्दाख में तनातनी के बीच सरकार ने कहा- 'चीनी सैनिकों ने आपसी सहमति के सभी मानदंडों की अवहेलना की'
# 2020-06-25 13:29:19+00:00
# Fast_Score =188.51666666666668
#
# idx =  13
# आपातकाल की बरसी पर PM मोदी का ट्वीट, 'लोकतंत्र की रक्षा करने वालों को नमन'
# 2020-06-25 07:35:53+00:00
# Fast_Score =-164.91666666666666
#
# Input text =  राज्य में भिंड-मुरैना हॉटस्पॉट बने; राजस्थान की सीमा से जांच के बाद ही एंट्री मिलेगी, अब तक 12482 कोरोना संक्रमित
#
# Time=  2020-06-25 08:26:05+00:00
#
# idx =  63
# लॉकडाउन में प्रभावित हुए रेहड़ी-पटरीवालों के लिए 1 जुलाई से शुरू होगी 'PM स्वनिधि योजना', मिलेगा सस्ता कर्ज
# 2020-06-25 11:22:18+00:00
# Fast_Score =176.21666666666667
#
# idx =  32
# सीमा विवाद पर भारत के कड़े रुख से ड्रैगन पस्त, LAC के 3 प्वाइंट से पीछे हटी चीनी सेना
# 2020-06-25 04:07:50+00:00
# Fast_Score =-258.25
#
# Input text =  आईआईटी बॉम्बे में इस साल क्लासरूम में पढ़ाई नहीं होगी, 62 साल में पहली बार पूरे सेमेस्टर में ऑनलाइन क्लासेस होंगी
#
# Time=  2020-06-25 08:08:52+00:00
#
# idx =  59
# दिल्ली में अब कोरोना पॉजिटिव मरीज को COVID केयर सेंटर जाना अनिवार्य नहीं, फैसले से पीछे हटे अनिल बैजल
# 2020-06-25 12:12:41+00:00
# Fast_Score =243.81666666666666
#
# idx =  36
# भारतीय योग का दुनियाभर में बज रहा डंका, इस देश में खुली पहली योग यूनिवर्सिटी
# 2020-06-24 07:30:04+00:00
# Fast_Score =-1478.8
#
# Input text =  शिवराज ने कहा कांग्रेस को धिक्कार है; पटवारी ने पीएम मोदी की आलोचना में कहा- एक बेटे के चक्कर में पांच बेटियां पैदा हो गईं
#
# Time=  2020-06-25 08:04:57+00:00
#
# idx =  13
# आपातकाल की बरसी पर PM मोदी का ट्वीट, 'लोकतंत्र की रक्षा करने वालों को नमन'
# 2020-06-25 07:35:53+00:00
# Fast_Score =-29.066666666666666
#
# idx =  44
# पुलवामा में सुरक्षाबलों और आतंकियों के बीच मुठभेड़, दो से तीन आतंकी घिरे होने की आशंका
# 2020-06-25 00:53:42+00:00
# Fast_Score =-431.25
#
# Input text =  कोरोना का खौफ कम नहीं हो रहा; खाली-खाली दिखे होटल-रेस्टोरेंट, जिम ट्रेनर्स सरकार पर भड़के
#
# Time=  2020-06-25 07:59:06+00:00
#
# idx =  1
# Exclusive: चीन की एक-एक चाल पर नजर रखेगा 'ध्रुव', IIT बॉम्बे ने बनाया भारत का पहला नेविगेशन रिसीवर चिप
# 2020-06-25 12:54:42+00:00
# Fast_Score =295.6
#
# idx =  63
# लॉकडाउन में प्रभावित हुए रेहड़ी-पटरीवालों के लिए 1 जुलाई से शुरू होगी 'PM स्वनिधि योजना', मिलेगा सस्ता कर्ज
# 2020-06-25 11:22:18+00:00
# Fast_Score =203.2
#
# Input text =  केन्या की अदालत ने चीन से 24 हजार करोड़ रुपए के करार को गैरकानूनी बताया; इस फैसले के खिलाफ केन्या सरकार अब सुप्रीम कोर्ट जाएगी
#
# Time=  2020-06-25 07:54:10+00:00
#
# idx =  53
# लद्दाख में तनातनी के बीच सरकार ने कहा- 'चीनी सैनिकों ने आपसी सहमति के सभी मानदंडों की अवहेलना की'
# 2020-06-25 13:29:19+00:00
# Fast_Score =335.15
#
# idx =  48
# रंगभेद खत्म करने की मुहिम: 'फेयर एंड लवली' से 'फेयर' हटाएगा हिंदुस्तान यूनिलीवर
# 2020-06-25 01:10:49+00:00
# Fast_Score =-403.35
#
# Input text =  बारामूला के सोपोर इलाके में सुरक्षाबलों ने 2 आतंकी मार गिराए; बडगाम में आतंकियों के 5 सहयोगी गिरफ्तार
#
# Time=  2020-06-25 07:50:23+00:00
#
# idx =  19
# जम्मू-कश्मीर के सोपोर में सुरक्षाबलों की बड़ी कामयाबी, 2 आतंकियों को मार गिराया
# 2020-06-25 03:00:20+00:00
# Fast_Score =-290.05
#
# idx =  44
# पुलवामा में सुरक्षाबलों और आतंकियों के बीच मुठभेड़, दो से तीन आतंकी घिरे होने की आशंका
# 2020-06-25 00:53:42+00:00
# Fast_Score =-416.68333333333334
#
# Input text =  कोरोना वैक्सीन जल्द बनाने का दबाव डालने से बड़ा खतरा, 65 साल पहले जल्दबाजी में बने पोलियो टीके से 70 हजार बच्चे दिव्यांग हो गए थे
#
# Time=  2020-06-25 07:49:13+00:00
#
# idx =  63
# लॉकडाउन में प्रभावित हुए रेहड़ी-पटरीवालों के लिए 1 जुलाई से शुरू होगी 'PM स्वनिधि योजना', मिलेगा सस्ता कर्ज
# 2020-06-25 11:22:18+00:00
# Fast_Score =213.08333333333334
#
# idx =  26
# अगले सप्ताह दुनियाभर होंगे कोरोना वायरस के 1 करोड़ मामले: WHO
# 2020-06-25 05:56:16+00:00
# Fast_Score =-112.95
#
# Input text =  अमेरिकी विदेश विभाग ने कहा- पाकिस्तान अब भी आतंकियों के लिए सुरक्षित पनाहगाह, वहां आतंकी गुटों की हिफाजत करती है सरकार
#
# Time=  2020-06-25 07:47:28+00:00
#
# idx =  53
# लद्दाख में तनातनी के बीच सरकार ने कहा- 'चीनी सैनिकों ने आपसी सहमति के सभी मानदंडों की अवहेलना की'
# 2020-06-25 13:29:19+00:00
# Fast_Score =341.85
#
# idx =  31
# PAK आतंकियों के लिये पनाहगाह, मुंबई हमले के मास्‍टरमाइंड के खिलाफ कार्रवाई नहीं हुई: US
# 2020-06-24 21:11:31+00:00
# Fast_Score =-635.95
#
# Input text =  76 नए पॉजिटिव मामले सामने आए, शादी का पहला न्यौता देने के लिए जोधपुर में बंद मंदिर के बाहर लगी लंबी कतार
#
# Time=  2020-06-25 06:28:42+00:00
#
# idx =  44
# पुलवामा में सुरक्षाबलों और आतंकियों के बीच मुठभेड़, दो से तीन आतंकी घिरे होने की आशंका
# 2020-06-25 00:53:42+00:00
# Fast_Score =-335.0
#
# idx =  63
# लॉकडाउन में प्रभावित हुए रेहड़ी-पटरीवालों के लिए 1 जुलाई से शुरू होगी 'PM स्वनिधि योजना', मिलेगा सस्ता कर्ज
# 2020-06-25 11:22:18+00:00
# Fast_Score =293.6
#
# Input text =  एक ही परिवार के 5 लोगों की गला रेत कर हत्या, 20 साल से नशा तस्करी के लिए बदनाम था यह कुनबा
#
# Time=  2020-06-25 06:15:23+00:00
#
# idx =  32
# सीमा विवाद पर भारत के कड़े रुख से ड्रैगन पस्त, LAC के 3 प्वाइंट से पीछे हटी चीनी सेना
# 2020-06-25 04:07:50+00:00
# Fast_Score =-127.55
#
# idx =  63
# लॉकडाउन में प्रभावित हुए रेहड़ी-पटरीवालों के लिए 1 जुलाई से शुरू होगी 'PM स्वनिधि योजना', मिलेगा सस्ता कर्ज
# 2020-06-25 11:22:18+00:00
# Fast_Score =306.9166666666667
#
# Input text =  नेपाल के तीन सांसदों की मांग- चीन ने हमारे 4 जिलों की 158 एकड़ जमीन पर कब्जा किया, प्रधानमंत्री इसे वापस दिलाएं
#
# Time=  2020-06-25 04:24:15+00:00
#
# idx =  32
# सीमा विवाद पर भारत के कड़े रुख से ड्रैगन पस्त, LAC के 3 प्वाइंट से पीछे हटी चीनी सेना
# 2020-06-25 04:07:50+00:00
# Fast_Score =-16.416666666666668
#
# idx =  12
# सीमा विवाद के बीच सरकार का बड़ा फैसला, लद्दाख में 54 मोबाइल टावर लगाने का काम शुरू
# 2020-06-25 07:45:05+00:00
# Fast_Score =200.83333333333334
#
# Input text =  छत्तीसगढ़ में मानसून आते मछुआरों की उम्मीदें बढ़ीं, झारखंड में बारिश के बाद जिंदगी टापू न बने इसलिए लोग बना रहे बांस का पुल
#
# Time=  2020-06-25 03:43:50+00:00
#
# idx =  0
# बिहार में आकाशीय बिजली ने मचाया कोहराम, अब तक 83 लोगों की हुई मौत
# 2020-06-25 13:50:01+00:00
# Fast_Score =606.1833333333333
#
# idx =  52
# संकट के समय भी जनता की जेब काटने में लगी है बीजेपी सरकार : प्रियंका गांधी
# 2020-06-25 13:37:53+00:00
# Fast_Score =594.05
#
# Input text =  इस बार मास्क बताएगा कौन किस दल का समर्थक; मुखौटे नहीं, सैनिटाइजर-पीपीई किट बंटेंगे
#
# Time=  2020-06-25 03:42:00+00:00
#
# idx =  69
# Reality Check: लद्दाख संघर्ष के बाद चीनी सामान पर BAN की मांग है कितनी व्‍यावहारिक और क्‍या हैं अड़चनें..
# 2020-06-25 10:31:03+00:00
# Fast_Score =409.05
#
# idx =  30
# आज ही के दिन दुनिया को अलविदा कह गए थे किंग ऑफ पॉप माइकल जैक्सन
# 2020-06-25 02:54:29+00:00
# Fast_Score =-47.516666666666666
#
# Input text =  'जिस तरह सूर्य की हर किरण पर अधिकार सबका है, उसी तरह भास्कर की हर खबर और विचार पर हक उसके पाठकों का है’
#
# Time=  2020-06-25 01:32:01+00:00
#
# idx =  69
# Reality Check: लद्दाख संघर्ष के बाद चीनी सामान पर BAN की मांग है कितनी व्‍यावहारिक और क्‍या हैं अड़चनें..
# 2020-06-25 10:31:03+00:00
# Fast_Score =539.0333333333333
#
# idx =  31
# PAK आतंकियों के लिये पनाहगाह, मुंबई हमले के मास्‍टरमाइंड के खिलाफ कार्रवाई नहीं हुई: US
# 2020-06-24 21:11:31+00:00
# Fast_Score =-260.5
#
# Input text =  मुरैना से लगी धौलपुर की सीमा को 10 दिन के लिए सील करने के आदेश, पुलिसबल तैनात
#
# Time=  2020-06-25 01:11:55+00:00
#
# idx =  63
# लॉकडाउन में प्रभावित हुए रेहड़ी-पटरीवालों के लिए 1 जुलाई से शुरू होगी 'PM स्वनिधि योजना', मिलेगा सस्ता कर्ज
# 2020-06-25 11:22:18+00:00
# Fast_Score =610.3833333333333
#
# idx =  12
# सीमा विवाद के बीच सरकार का बड़ा फैसला, लद्दाख में 54 मोबाइल टावर लगाने का काम शुरू
# 2020-06-25 07:45:05+00:00
# Fast_Score =393.1666666666667
#
# Input text =  जेपी नड्डा की वर्चुअल रैली में एक करोड़ लोगों को जोड़ेगी भाजपा, सिंधिया ने वीडियो जारी कर कार्यकर्ताओं से जुड़ने का अनुरोध किया
#
# Time=  2020-06-25 01:11:51+00:00
#
# idx =  56
# पेट्रोल, डीज़ल और रसोई गैस की बढ़ती कीमतों के विरोध में RJD नेता तेजस्वी यादव ने निकाला साइकिल मार्च
# 2020-06-25 13:08:40+00:00
# Fast_Score =716.8166666666667
#
# idx =  63
# लॉकडाउन में प्रभावित हुए रेहड़ी-पटरीवालों के लिए 1 जुलाई से शुरू होगी 'PM स्वनिधि योजना', मिलेगा सस्ता कर्ज
# 2020-06-25 11:22:18+00:00
# Fast_Score =610.45
#
# Input text =  फाइनेंशियल एक्शन टास्क फोर्स ने कहा- लश्कर और जैश जैसे आतंकी संगठनों की फंडिंग रोकने में पाक नाकाम, ग्रे लिस्ट में ही रहेगा
#
# Time=  2020-06-25 01:04:55+00:00
#
# idx =  61
# जेपी नड्डा ने राहुल से पूछा सवाल, राजीव गांधी फाउंडेशन को चीन से डोनेशन क्यों मिला?
# 2020-06-25 11:59:11+00:00
# Fast_Score =654.2666666666667
#
# idx =  56
# पेट्रोल, डीज़ल और रसोई गैस की बढ़ती कीमतों के विरोध में RJD नेता तेजस्वी यादव ने निकाला साइकिल मार्च
# 2020-06-25 13:08:40+00:00
# Fast_Score =723.75
#
# Input text =  नए वीजा नियमों से 1000 से ज्यादा लोग भारत में फंसे; ज्यादातर के परिवार अमेरिका में परेशान हैं
#
# Time=  2020-06-25 01:00:39+00:00
#
# idx =  32
# सीमा विवाद पर भारत के कड़े रुख से ड्रैगन पस्त, LAC के 3 प्वाइंट से पीछे हटी चीनी सेना
# 2020-06-25 04:07:50+00:00
# Fast_Score =187.18333333333334
#
# idx =  69
# Reality Check: लद्दाख संघर्ष के बाद चीनी सामान पर BAN की मांग है कितनी व्‍यावहारिक और क्‍या हैं अड़चनें..
# 2020-06-25 10:31:03+00:00
# Fast_Score =570.4
#
# Input text =  अमेरिका में पटाखों से परेशान लोगों ने मेयर के घर के बाहर रातभर हॉर्न बजाया; सुबह नए नियम बन गए
#
# Time=  2020-06-25 01:00:12+00:00
#
# idx =  32
# सीमा विवाद पर भारत के कड़े रुख से ड्रैगन पस्त, LAC के 3 प्वाइंट से पीछे हटी चीनी सेना
# 2020-06-25 04:07:50+00:00
# Fast_Score =187.63333333333333
#
# idx =  12
# सीमा विवाद के बीच सरकार का बड़ा फैसला, लद्दाख में 54 मोबाइल टावर लगाने का काम शुरू
# 2020-06-25 07:45:05+00:00
# Fast_Score =404.8833333333333
#
# Input text =  गलवान में जहां विवाद हुआ, वहां चीन ने फिर अपने टेंट लगाए; भारतीय फाइटर जेट्स ने भी इस जगह के ऊपर उड़ान भरी
#
# Time=  2020-06-25 00:41:18+00:00
#
# idx =  12
# सीमा विवाद के बीच सरकार का बड़ा फैसला, लद्दाख में 54 मोबाइल टावर लगाने का काम शुरू
# 2020-06-25 07:45:05+00:00
# Fast_Score =423.78333333333336
#
# idx =  32
# सीमा विवाद पर भारत के कड़े रुख से ड्रैगन पस्त, LAC के 3 प्वाइंट से पीछे हटी चीनी सेना
# 2020-06-25 04:07:50+00:00
# Fast_Score =206.53333333333333
#
# Input text =  डीजीसीए ने एयरलाइंस से कहा- यात्रियों पर दबाव बढ़ा, पैसेंजर्स और क्रू में विवाद हो सकता है; क्रू को हालात संभालने की ट्रेनिंग दें
#
# Time=  2020-06-25 00:37:32+00:00
#
# idx =  53
# लद्दाख में तनातनी के बीच सरकार ने कहा- 'चीनी सैनिकों ने आपसी सहमति के सभी मानदंडों की अवहेलना की'
# 2020-06-25 13:29:19+00:00
# Fast_Score =771.7833333333333
#
# idx =  12
# सीमा विवाद के बीच सरकार का बड़ा फैसला, लद्दाख में 54 मोबाइल टावर लगाने का काम शुरू
# 2020-06-25 07:45:05+00:00
# Fast_Score =427.55
